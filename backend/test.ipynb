# %%
from model_loader import load_all_assets

assets = load_all_assets()

print(assets.keys())
print(assets["device"])
print(type(assets["lr_model"]))
print(type(assets["rf_model"]))
print(type(assets["lstm_model"]))
print(assets["lstm_metadata"]["feature_count"])
print(assets["preprocessing_artifacts"]["window_size"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from CMAPSS_Foreasting.backend.model_loader import load_all_assets
#       3 assets = load_all_assets()
#       5 print(assets.keys())
#
# ModuleNotFoundError: No module named 'CMAPSS_Foreasting'
